# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Used Car Dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                           car_name  \
# 0           0                    2017 Mercedes-Benz S-Class S400
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
# 3           3                           2019 Kia Seltos GTX Plus
# 4           4                    2019 Skoda Superb LK 1.8 TSI AT
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            Jul-17      Comprehensive    Petrol      5       56000
# 1            Jan-21      Comprehensive    Petrol      5       30615
# 2            Sep-18      Comprehensive    Diesel      5       24000
# 3            Dec-19      Comprehensive    Petrol      5       18378
# 4            Aug-19      Comprehensive    Petrol      5       44900
#
#     ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic               2017           7.81      2996.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553 entries, 0 to 1552
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1553 non-null   int64
#  1   car_name            1553 non-null   object
#  2   registration_year   1553 non-null   object
#  3   insurance_validity  1553 non-null   object
#  4   fuel_type           1553 non-null   object
#  5   seats               1553 non-null   int64
#  6   kms_driven          1553 non-null   int64
#  7   ownsership          1553 non-null   object
#  8   transmission        1553 non-null   object
#  9   manufacturing_year  1553 non-null   object
#  10  mileage(kmpl)       1550 non-null   float64
#  11  engine(cc)          1550 non-null   float64
#  12  max_power(bhp)      1550 non-null   float64
#  13  torque(Nm)          1549 non-null   float64
#  14  price(in lakhs)     1553 non-null   float64
# ...

# %%
df.shape
# Out:
# (1553, 15)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         3
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            4
# price(in lakhs)       0
# dtype: int64

# %%
df['mileage(kmpl)'].fillna(df['mileage(kmpl)'].mean(),inplace=True)
df['engine(cc)'].fillna(df['engine(cc)'].mean(),inplace=True)
df['max_power(bhp)'].fillna(df['max_power(bhp)'].mean(),inplace=True)
df['torque(Nm)'].fillna(df['torque(Nm)'].median(),inplace=True)

# %%
df
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         0
# engine(cc)            0
# max_power(bhp)        0
# torque(Nm)            0
# price(in lakhs)       0
# dtype: int64

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df.loc[(df.ownsership == 'First Owner')  |
                (df.ownsership == 'Second Owner') |
                (df.ownsership == 'Third Owner')|
                (df.ownsership=='Fifth Owner')
             ]
# Out:
#                                                car_name registration_year  \
# 0                       2017 Mercedes-Benz S-Class S400            Jul-17
# 1     2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                          2018 BMW X1 sDrive 20d xLine            Sep-18
# 3                              2019 Kia Seltos GTX Plus            Dec-19
# 4                       2019 Skoda Superb LK 1.8 TSI AT            Aug-19
# ...                                                 ...               ...
# 1547                         2022 Maruti Ertiga VXI CNG            May-22
# 1548           2020 Hyundai Creta SX Opt Diesel AT BSVI            Aug-20
# 1550                           2017 Honda WR-V i-VTEC S            Jun-17
# 1551           2018 Volkswagen Polo 1.0 MPI Comfortline            May-18
# 1552                        2018 Maruti Swift Dzire VXI            May-18
#
#          insurance_validity fuel_type  seats  kms_driven    ownsership  \
# ...

# %%
df
# Out:
#                                                car_name registration_year  \
# 0                       2017 Mercedes-Benz S-Class S400            Jul-17
# 1     2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                          2018 BMW X1 sDrive 20d xLine            Sep-18
# 3                              2019 Kia Seltos GTX Plus            Dec-19
# 4                       2019 Skoda Superb LK 1.8 TSI AT            Aug-19
# ...                                                 ...               ...
# 1548           2020 Hyundai Creta SX Opt Diesel AT BSVI            Aug-20
# 1549                 2022 Renault KWID 1.0 RXL Opt BSVI              2022
# 1550                           2017 Honda WR-V i-VTEC S            Jun-17
# 1551           2018 Volkswagen Polo 1.0 MPI Comfortline            May-18
# 1552                        2018 Maruti Swift Dzire VXI            May-18
#
#          insurance_validity fuel_type  seats  kms_driven    ownsership  \
# ...

# %%
df.loc[(df.transmission == 'Automatic')  |
                (df.transmission == 'Manual')  ]
# Out:
#                                                car_name registration_year  \
# 0                       2017 Mercedes-Benz S-Class S400            Jul-17
# 1     2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                          2018 BMW X1 sDrive 20d xLine            Sep-18
# 3                              2019 Kia Seltos GTX Plus            Dec-19
# 4                       2019 Skoda Superb LK 1.8 TSI AT            Aug-19
# ...                                                 ...               ...
# 1547                         2022 Maruti Ertiga VXI CNG            May-22
# 1548           2020 Hyundai Creta SX Opt Diesel AT BSVI            Aug-20
# 1550                           2017 Honda WR-V i-VTEC S            Jun-17
# 1551           2018 Volkswagen Polo 1.0 MPI Comfortline            May-18
# 1552                        2018 Maruti Swift Dzire VXI            May-18
#
#          insurance_validity fuel_type  seats  kms_driven    ownsership  \
# ...

# %%
df
# Out:
#                                                car_name registration_year  \
# 0                       2017 Mercedes-Benz S-Class S400            Jul-17
# 1     2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                          2018 BMW X1 sDrive 20d xLine            Sep-18
# 3                              2019 Kia Seltos GTX Plus            Dec-19
# 4                       2019 Skoda Superb LK 1.8 TSI AT            Aug-19
# ...                                                 ...               ...
# 1548           2020 Hyundai Creta SX Opt Diesel AT BSVI            Aug-20
# 1549                 2022 Renault KWID 1.0 RXL Opt BSVI              2022
# 1550                           2017 Honda WR-V i-VTEC S            Jun-17
# 1551           2018 Volkswagen Polo 1.0 MPI Comfortline            May-18
# 1552                        2018 Maruti Swift Dzire VXI            May-18
#
#          insurance_validity fuel_type  seats  kms_driven    ownsership  \
# ...

# %%
df_encoded=pd.get_dummies(df,columns=['fuel_type','ownsership','transmission'],drop_first=True)
print(df_encoded.head)
# Out:
# <bound method NDFrame.head of                                                car_name registration_year  \
# 0                       2017 Mercedes-Benz S-Class S400            Jul-17
# 1     2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                          2018 BMW X1 sDrive 20d xLine            Sep-18
# 3                              2019 Kia Seltos GTX Plus            Dec-19
# 4                       2019 Skoda Superb LK 1.8 TSI AT            Aug-19
# ...                                                 ...               ...
# 1548           2020 Hyundai Creta SX Opt Diesel AT BSVI            Aug-20
# 1549                 2022 Renault KWID 1.0 RXL Opt BSVI              2022
# 1550                           2017 Honda WR-V i-VTEC S            Jun-17
# 1551           2018 Volkswagen Polo 1.0 MPI Comfortline            May-18
# 1552                        2018 Maruti Swift Dzire VXI            May-18
#
# ...

# %%
df_encoded
# Out:
#                                                car_name registration_year  \
# 0                       2017 Mercedes-Benz S-Class S400            Jul-17
# 1     2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                          2018 BMW X1 sDrive 20d xLine            Sep-18
# 3                              2019 Kia Seltos GTX Plus            Dec-19
# 4                       2019 Skoda Superb LK 1.8 TSI AT            Aug-19
# ...                                                 ...               ...
# 1548           2020 Hyundai Creta SX Opt Diesel AT BSVI            Aug-20
# 1549                 2022 Renault KWID 1.0 RXL Opt BSVI              2022
# 1550                           2017 Honda WR-V i-VTEC S            Jun-17
# 1551           2018 Volkswagen Polo 1.0 MPI Comfortline            May-18
# 1552                        2018 Maruti Swift Dzire VXI            May-18
#
#          insurance_validity  seats  kms_driven manufacturing_year  \
# ...

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553 entries, 0 to 1552
# Data columns (total 47 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   car_name                          1553 non-null   object
#  1   registration_year                 1553 non-null   object
#  2   insurance_validity                1553 non-null   object
#  3   seats                             1553 non-null   int64
#  4   kms_driven                        1553 non-null   int64
#  5   manufacturing_year                1553 non-null   object
#  6   mileage(kmpl)                     1553 non-null   float64
#  7   engine(cc)                        1553 non-null   float64
#  8   max_power(bhp)                    1553 non-null   float64
#  9   torque(Nm)                        1553 non-null   float64
#  10  price(in lakhs)                   1553 non-null   float64
# ...

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553 entries, 0 to 1552
# Data columns (total 47 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   car_name                          1553 non-null   object
#  1   registration_year                 1553 non-null   object
#  2   insurance_validity                1553 non-null   object
#  3   seats                             1553 non-null   int64
#  4   kms_driven                        1553 non-null   int64
#  5   manufacturing_year                1553 non-null   object
#  6   mileage(kmpl)                     1553 non-null   float64
#  7   engine(cc)                        1553 non-null   float64
#  8   max_power(bhp)                    1553 non-null   float64
#  9   torque(Nm)                        1553 non-null   float64
#  10  price(in lakhs)                   1553 non-null   float64
# ...
